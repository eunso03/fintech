# %% [markdown]
# # 연산자의 종류
# * 산술, 할당, 비교, 논리, 식별, 멤버

# %% [markdown]
# # 산술연산자 +, -, *, /, %, //, **

# %%
1+1
# Out:
# 2

# %%
2+3.1
# Out:
# 5.1

# %%
3-4
# Out:
# -1

# %%
5*3
# Out:
# 15

# %%
5/3
# Out:
# 1.6666666666666667

# %%
4/2
# Out:
# 2.0

# %% [markdown]
# %는 나머지를 구하는 연산자 (%2로 0이면 짝수 1이면 홀수)

# %%
3%2
# Out:
# 1

# %%
4%2
# Out:
# 0

# %%
15%2
# Out:
# 1

# %% [markdown]
# // 몫을 구하는 연산자

# %%
7//3
# Out:
# 2

# %% [markdown]
# ** 제곱

# %%
2**3
# Out:
# 8

# %% [markdown]
# # 할당 연산자
# * =, +=, -=, /=, %=

# %%
a = 10
b = 5

# %%
a = a+5
a
# Out:
# 15

# %%
a += 5
a
# Out:
# 20

# %%
b -=10
b
# Out:
# -5

# %%
a *= 5
a
# Out:
# 100

# %%
a /= 5
a
# Out:
# 20.0

# %%
a %= 2
a
# Out:
# 0.0

# %% [markdown]
# # 비교 연산자
# * 같다 ==
# * 다르다  !=
# * 초과 >
# * 미만 <
# * 이상 >=
# * 이하 <=

# %% [markdown]
# * == 같으면 True, 다르면 False

# %%
a=3
b=3.0
c=5
d="Python"
e="python"
f=True
g=False

# %%
a==b
# Out:
# True

# %%
a==c
# Out:
# False

# %%
d==e
# Out:
# False

# %% [markdown]
# * != 다르면 True, 같으면 False

# %%
a != b
# Out:
# False

# %%
a != c
# Out:
# True

# %%
d != e
# Out:
# True

# %%
print(a)
print(b)
a > b
# Out:
# 3
# 3.0
# False

# %%
print(a)
print(c)
a > c
# Out:
# 3
# 5
# False

# %%
print(a)
print(b)
a >= b
# Out:
# 3
# 3.0
# True

# %% [markdown]
# # 논리 연산자
# * and, or, not

# %% [markdown]
# and는 두 값이 모두 참이어야 참

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %% [markdown]
# or 두 값중 하나라도 참이면 참, 두 값 모두가 거짓이어야 거짓

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %% [markdown]
# not 값을 반대로 뒤집음 True=>False, False=>True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# * and, or, not의 우선순위
# * not, and, or 순으로 판단

# %%
not True and False or not False
# Out:
# True

# %%
10 == 10 and 10 != 5
# Out:
# True

# %% [markdown]
# # 식별 연산자
# * is, is not(object, data type)이 같은지 비교

# %%
print(a)
print(b)
print(c)
# Out:
# 3
# 3.0
# 5

# %%
print(a == b) # a는 정수 3, b는 실수 3.0이라 값이 같음
print(a is b) # a는 정수 3, b는 실수 3.0이라 데이터 타입이 달라서 False
# Out:
# True
# False

# %%
d = 3

# %%
print(a is d) # a와 d가 모두 int 3이기 때문에 True
# Out:
# True

# %%
print(a is not b)
# Out:
# True

# %% [markdown]
# # 멤버 연산자
# * in, not in

# %%
mem = [1,2,3,4,5]

# %%
3 in mem
# Out:
# True

# %%
10 in mem
# Out:
# False

# %%
10 not in mem
# Out:
# True

# %%
3 not in mem
# Out:
# False
