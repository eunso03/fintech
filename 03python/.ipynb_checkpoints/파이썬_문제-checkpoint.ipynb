# %% [markdown]
# # 파이썬 시작하기

# %% [markdown]
# 1. 화면에 `Hello World` 문자열을 출력하세요.

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# 2. 화면에 `Mary's cosmetics`을 출력하세요. (중간에 '가 있음에 주의하세요)

# %%
print("Mary's cosmetics")
# Out:
# Mary's cosmetics

# %% [markdown]
# 3. 화면에 아래 문장을 출력하세요. (중간에 "가 있음에 주의하세요.)<br>
# ` 신씨가 소리질렀다. "도둑이야". `

# %%
print('신씨가 소리질렀다. "도둑이야."')
# Out:
# 신씨가 소리질렀다. "도둑이야."

# %% [markdown]
# 4. 화면에 `C:\Windows`를 출력하세요.

# %%
print("C:\Windows")
# Out:
# C:\Windows

# %% [markdown]
# 5. 다음 코드를 실행해보고 \t와 \n의 역할을 설명해보세요.<br>
# `print("안녕하세요.\n만나서\t\t반갑습니다.")`

# %%
print("안녕하세요.\n만나서\t\t반갑습니다.")
# \n은 줄바꿈 / \t는 tab(들여쓰기)
# Out:
# 안녕하세요.
# 만나서		반갑습니다.

# %% [markdown]
# 6. print 함수에 두 개의 단어를 입력한 예제입니다. 아래 코드의 출력 결과를 예상해봅시다.<br>
# `print ("오늘은", "일요일")`

# %%
print ("오늘은", "일요일")
# 오늘은 일요일
# Out:
# 오늘은 일요일

# %% [markdown]
# 7. print() 함수를 사용하여 다음과 같이 출력하세요.<br>
# `naver;kakao;sk;samsung`

# %%
print("naver", "kakao", "sk", "samsung", sep=";")
# Out:
# naver;kakao;sk;samsung

# %% [markdown]
# 8. print() 함수를 사용하여 다음과 같이 출력하세요.<br>
# `naver/kakao/sk/samsung`

# %%
print("naver", "kakao", "sk", "samsung", sep="/")
# Out:
# naver/kakao/sk/samsung

# %% [markdown]
# 9. 다음 코드를 수정하여 줄바꿈이 없이 출력하세요. (힌트: end='') print 함수는 두 번 사용합니다. 세미콜론 (;)은 한줄에 여러 개의 명령을 작성하기 위해 사용합니다.<br>
# `print("first");print("second")`

# %%
print("first", end="");print("second")
# Out:
# firstsecond

# %% [markdown]
# 10. 5/3의 결과를 화면에 출력하세요.

# %%
print(5/3)
# Out:
# 1.6666666666666667

# %% [markdown]
# # 파이썬 변수

# %% [markdown]
# 11. 삼성전자라는 변수로 50,000원을 바인딩해보세요. 삼성전자 주식 10주를 보유하고 있을 때 총 평가금액을 출력하세요.

# %%
삼성전자 = 50000
print(삼성전자 * 10)
# Out:
# 500000

# %% [markdown]
# 12. 다음 표는 삼성전자의 일부 투자정보입니다. 변수를 사용해서 시가총액, 현재가, PER 등을 바인딩해보세요.<br>
# | 항목     | 값       |
# |---------|---------|
# | 시가총액 | 298조   |
# | 현재가   | 50,000원 |
# | PER     | 15.79   |

# %%
시가총액 = 298000000000000
현재가 = 50000
PER = 15.79
print(시가총액)
print(현재가)
print(PER)
# Out:
# 298000000000000
# 50000
# 15.79

# %% [markdown]
# 13. 변수 s와 t에는 각각 문자열이 바인딩 되어있습니다.<br>
# `s = "hello"`<br>
# `t = "python"`<br>
# 두 변수를 이용하여 아래와 같이 출력해보세요.<br>
# `hello! python`

# %%
s = "hello"
t = "python"
print(s + "!", t)
# Out:
# hello! python

# %% [markdown]
# 14. 아래 코드의 실행 결과를 예상해보세요.<br>
# `2 + 2 * 3 `

# %%
print(2 + 2 * 3)
# 8
# Out:
# 8

# %% [markdown]
# 15. type() 함수는 데이터 타입을 판별합니다. 변수 a에는 128 숫자가 바인딩돼 있어 type 함수가 int (정수)형임을 알려줍니다.<br>
# `a = 128`<br>
# `print (type(a))`<br>
# `<class 'int'>`<br>
# 아래 변수에 바인딩된 값의 타입을 판별해보세요.<br>
# `a = "132"`

# %%
a = 132
print(type(a))
# Out:
# <class 'int'>

# %% [markdown]
# 16. 문자열 '720'를 정수형으로 변환해보세요.<br>
# `num_str = "720"`

# %%
num_str = "720"
num_str = int(num_str)
print(num_str, type(num_str))
# Out:
# 720 <class 'int'>

# %% [markdown]
# 17. 정수 100을 문자열 '100'으로 변환해보세요.<br>
# `num = 100`

# %%
num = 100
num = str(num)
print(num, type(num))
# Out:
# 100 <class 'str'>

# %% [markdown]
# 18. 문자열 "15.79"를 실수(float) 타입으로 변환해보세요.

# %%
s = float("15.79")
print(s, type(s))
# Out:
# 15.79 <class 'float'>

# %% [markdown]
# 19. year라는 변수가 문자열 타입의 연도를 바인딩하고 있습니다. 이를 정수로 변환한 후 최근 3년의 연도를 화면에 출력해보세요.<br>
# `year = "2020"`

# %%
year = "2020"
year = int(year)
print(year-1)
print(year-2)
print(year-3)
# Out:
# 2019
# 2018
# 2017

# %% [markdown]
# 20. 에이컨이 월 48,584원에 무이자 36개월의 조건으로 홈쇼핑에서 판매되고 있습니다. 총 금액은 계산한 후 이를 화면에 출력해보세요. (변수사용하기)

# %%
price = 48584
sum = price * 36
print(sum)
# Out:
# 1749024

# %% [markdown]
# #  파이썬 문자열

# %% [markdown]
# 21. letters가 바인딩하는 문자열에서 첫번째와 세번째 문자를 출력하세요.<br>
# `letters = 'python'`<br>
# `실행 예`<br>
# `p t`

# %%
letters = 'python'
print(letters[0], letters[2])
# Out:
# p t

# %% [markdown]
# 22. 자동차 번호가 다음과 같을 때 뒤에 4자리만 출력하세요.<br>
# `license_plate = "24가 2210"`<br>
# `실행 예: 2210`

# %%
license_plate = "24가 2210"
print(license_plate[4:])
# Out:
# 2210

# %% [markdown]
# 23. 아래의 문자열에서 '홀' 만 출력하세요.<br>
# `string = "홀짝홀짝홀짝"`<br>
# `실행 예:`<br>
# `홀홀홀`

# %%
string = "홀짝홀짝홀짝"
print(string[0::2])
# Out:
# 홀홀홀

# %% [markdown]
# 24. 문자열을 거꾸로 뒤집어 출력하세요.<br>
# `string = "PYTHON"`<br>
# `실행 예:`<br>
# `NOHTYP`

# %%
string = "PYTHON"
print(string[::-1])
# Out:
# NOHTYP

# %% [markdown]
# 25. 아래의 전화번호에서 하이푼 ('-')을 제거하고 출력하세요.<br>
# `phone_number = "010-1111-2222"`<br>
# `실행 예`<br>
# `010 1111 2222`

# %%
phone_number = "010-1111-2222"
print(phone_number.replace("-", " "))
# Out:
# 010 1111 2222

# %% [markdown]
# 26. 25번 문제의 전화번호를 아래와 같이 모두 붙여 출력하세요.<br>
# `실행 예`<br>
# `01011112222`

# %%
print(phone_number.replace("-", " ").replace(" ", ""))
# Out:
# 01011112222

# %% [markdown]
# 27. url 에 저장된 웹 페이지 주소에서 도메인을 출력하세요.<br>
# `url = "http://sharebook.kr"`<br>
# `실행 예:`<br>
# `kr`

# %%
url = "http://sharebook.kr"
url_split = url.split('.')
print(url_split[-1])
# Out:
# kr

# %% [markdown]
# 28. 아래 코드의 실행 결과를 예상해보세요.<br>
# `lang = 'python'`<br>
# `lang[0] = 'P'`<br>
# `print(lang)`

# %%
lang = 'python'
lang[0] = 'P'
print(lang)
# 오류 : 문자열은 수정 불가
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 lang = 'python'
# ----> 2 lang[0] = 'P'
#       3 print(lang)
#       4 # Python
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# 29. 아래 문자열에서 소문자 'a'를 대문자 'A'로 변경하세요.<br>
# `string = 'abcdfe2a354a32a'`<br>
# `실행 예:`<br>
# `Abcdfe2A354A32A`

# %%
string = 'abcdfe2a354a32a'
string = string.replace('a', 'A')
print(string)
# Out:
# Abcdfe2A354A32A

# %% [markdown]
# 30. 아래 코드의 실행 결과를 예상해보세요.<br>
# `string = 'abcd'`<br>
# `string.replace('b', 'B')`<br>
# `print(string)`

# %%
string = 'abcd'
string.replace('b', 'B')
print(string)
# abcd : 문자열은 변경할 수 없기 때문에 원본 데이터가 출력됨
# Out:
# abcd
